# %%
import pandas as pd
import numpy as np
import math

# %%
#Loads crime data from LA and displays it
crime = pd.read_csv('la_crime.csv')
crime
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 990288  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 990289  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 990290  240410786  10/14/2024 12:00:00 AM  10/11/2024 12:00:00 AM      2330
# 990291  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 990292  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
#         AREA   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          7    Wilshire          784         1     510
# 1          1     Central          182         1     330
# 2          3   Southwest          356         1     480
# 3          9    Van Nuys          964         1     343
# 4          6   Hollywood          666         2     354
# ...      ...         ...          ...       ...     ...
# 990288     7    Wilshire          788         1     510
# 990289     1     Central          101         2     745
# 990290     4  Hollenbeck          421         1     341
# 990291     3   Southwest          358         1     230
# 990292     9    Van Nuys          914         1     510
#
#                                               Crm Cd Desc  ... Status  \
# 0                                        VEHICLE - STOLEN  ...     AA
# 1                                   BURGLARY FROM VEHICLE  ...     IC
# 2                                           BIKE - STOLEN  ...     IC
# 3                SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC
# 4                                       THEFT OF IDENTITY  ...     IC
# ...                                                   ...  ...    ...
# 990288                                   VEHICLE - STOLEN  ...     IC
# 990289           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 990290  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...     IC
# 990291     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 990292                                   VEHICLE - STOLEN  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0       Adult Arrest    510.0    998.0       NaN      NaN
# 1        Invest Cont    330.0    998.0       NaN      NaN
# 2        Invest Cont    480.0      NaN       NaN      NaN
# 3        Invest Cont    343.0      NaN       NaN      NaN
# 4        Invest Cont    354.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 990288   Invest Cont    510.0      NaN       NaN      NaN
# 990289   Invest Cont    745.0      NaN       NaN      NaN
# 990290   Invest Cont    341.0      NaN       NaN      NaN
# 990291   Invest Cont    230.0      NaN       NaN      NaN
# 990292   Invest Cont    510.0      NaN       NaN      NaN
#
#                                         LOCATION  \
# 0        1900 S  LONGWOOD                     AV
# 1        1000 S  FLOWER                       ST
# 2        1400 W  37TH                         ST
# 3       14000    RIVERSIDE                    DR
# 4                              1900    TRANSIENT
# ...                                          ...
# 990288   4000 W  23RD                         ST
# 990289   1300 W  SUNSET                       BL
# 990290   1700    ALBION                       ST
# 990291           FLOWER                       ST
# 990292   6900    VESPER                       AV
#
#                            Cross Street      LAT       LON
# 0                                   NaN  34.0375 -118.3506
# 1                                   NaN  34.0444 -118.2628
# 2                                   NaN  34.0210 -118.3002
# 3                                   NaN  34.1576 -118.4387
# 4                                   NaN  34.0944 -118.3277
# ...                                 ...      ...       ...
# 990288                              NaN  34.0362 -118.3284
# 990289                              NaN  34.0685 -118.2460
# 990290                              NaN  34.0675 -118.2240
# 990291  JEFFERSON                    BL  34.0215 -118.2868
# 990292                              NaN  34.1961 -118.4510
#
# [990293 rows x 28 columns]

# %%
#Filters columns in dataframe to ones relevant to our project
crime_cf = crime.get(['DATE OCC', 'AREA', 'AREA NAME','Crm Cd', 'Status Desc', 'LOCATION', 'LAT', 'LON'])
crime_cf
# Out:
#                       DATE OCC  AREA   AREA NAME  Crm Cd   Status Desc  \
# 0       03/01/2020 12:00:00 AM     7    Wilshire     510  Adult Arrest
# 1       02/08/2020 12:00:00 AM     1     Central     330   Invest Cont
# 2       11/04/2020 12:00:00 AM     3   Southwest     480   Invest Cont
# 3       03/10/2020 12:00:00 AM     9    Van Nuys     343   Invest Cont
# 4       08/17/2020 12:00:00 AM     6   Hollywood     354   Invest Cont
# ...                        ...   ...         ...     ...           ...
# 990288  07/23/2024 12:00:00 AM     7    Wilshire     510   Invest Cont
# 990289  01/15/2024 12:00:00 AM     1     Central     745   Invest Cont
# 990290  10/11/2024 12:00:00 AM     4  Hollenbeck     341   Invest Cont
# 990291  04/24/2024 12:00:00 AM     3   Southwest     230   Invest Cont
# 990292  08/12/2024 12:00:00 AM     9    Van Nuys     510   Invest Cont
#
#                                         LOCATION      LAT       LON
# 0        1900 S  LONGWOOD                     AV  34.0375 -118.3506
# 1        1000 S  FLOWER                       ST  34.0444 -118.2628
# 2        1400 W  37TH                         ST  34.0210 -118.3002
# 3       14000    RIVERSIDE                    DR  34.1576 -118.4387
# 4                              1900    TRANSIENT  34.0944 -118.3277
# ...                                          ...      ...       ...
# 990288   4000 W  23RD                         ST  34.0362 -118.3284
# 990289   1300 W  SUNSET                       BL  34.0685 -118.2460
# 990290   1700    ALBION                       ST  34.0675 -118.2240
# 990291           FLOWER                       ST  34.0215 -118.2868
# 990292   6900    VESPER                       AV  34.1961 -118.4510
#
# [990293 rows x 8 columns]

# %%
#Filters rows to only inlcude crimes that are relevant to guardia, using crime codes
codes = [
    187,    # Murder
    207,    # Kidnapping
    211,    # Robbery
    215,    # Carjacking
    240,    # Assault
    242,    # Battery
    245,    # Assault with a Deadly Weapon
    261,    # Rape
    288,    # Lewd Acts with a Child
    314,    # Indecent Exposure
    368,    # Elder or Dependent Adult Abuse
    415,    # Disturbing the Peace
    417,    # Brandishing a Weapon
    422,    # Criminal Threats
    451,    # Arson
    459,    # Burglary
    470,    # Forgery
    484,    # Theft
    487,    # Grand Theft
    488,    # Petty Theft
    496,    # Receiving Stolen Property
    537,    # Defrauding an Innkeeper
    594,    # Vandalism
    602,    # Trespassing
    647,    # Disorderly Conduct
    664,    # Attempted Crimes
    11350,  # Possession of Controlled Substances
    10851   # Vehicle Theft
]

codes = np.array(codes)
crime_rf = crime_cf[crime_cf['Crm Cd'].isin(codes)]
crime_rf.sort_values('Crm Cd')
# Out:
#                       DATE OCC  AREA    AREA NAME  Crm Cd  Status Desc  \
# 494433  06/12/2022 12:00:00 AM    15  N Hollywood     451  Invest Cont
# 616971  02/17/2022 12:00:00 AM    13       Newton     451  Invest Cont
# 161974  06/16/2020 12:00:00 AM    12  77th Street     451    Juv Other
# 717627  07/08/2023 12:00:00 AM    13       Newton     451  Invest Cont
# 622860  12/24/2022 12:00:00 AM     3    Southwest     451  Invest Cont
# ...                        ...   ...          ...     ...          ...
# 327437  12/22/2021 12:00:00 AM    16     Foothill     664  Invest Cont
# 327486  01/20/2021 12:00:00 AM     6    Hollywood     664  Invest Cont
# 327778  07/05/2021 12:00:00 AM    18    Southeast     664  Invest Cont
# 325294  07/06/2021 12:00:00 AM    14      Pacific     664  Invest Cont
# 989174  02/04/2024 12:00:00 AM    11    Northeast     664  Invest Cont
#
#                                        LOCATION      LAT       LON
# 494433          GAULT                        ST  34.1994 -118.4116
# 616971          AVALON                       BL  34.0153 -118.2653
# 161974  5700 S  VERMONT                      AV  33.9905 -118.2915
# 717627          AVALON                       BL  34.0102 -118.2653
# 622860  1400 W  ADAMS                        BL  34.0349 -118.2959
# ...                                         ...      ...       ...
# 327437  6500    FOOTHILL                     BL  34.2519 -118.2713
# 327486  7700    HOLLYWOOD                    BL  34.1017 -118.3574
# 327778  8600 S  CENTRAL                      AV  33.9595 -118.2564
# 325294  8800 S  SEPULVEDA                    BL  33.9579 -118.4020
# 989174                         100 E  AVENUE 40  34.0921 -118.2105
#
# [2989 rows x 8 columns]

# %%
crime = pd.read_csv('sd_crime.csv')
crime
# Out:
#         Incident UID           Incident Date CIBRS Unique Offense ID  \
# 0             452623  01/07/2021 12:01:00 AM              452623-26B
# 1            1083256  01/09/2021 07:30:00 AM             1083256-35A
# 2             435409  01/13/2021 03:00:00 PM              435409-23H
# 3             736456  01/17/2021 05:05:00 PM       736456-13A-758591
# 4            1249353  01/28/2021 09:31:00 PM             1249353-35A
# ...              ...                     ...                     ...
# 510584       2333674  09/29/2024 07:00:00 PM     2333674-13B-2046757
# 510585       2334461  09/28/2024 12:00:01 AM     2334461-13A-2047403
# 510586       2337500  09/30/2024 03:10:00 PM             2337500-120
# 510587       2331943  09/27/2024 03:20:00 PM             2331943-35A
# 510588       2335474  09/30/2024 09:00:00 PM             2335474-240
#
#        Crime Against Category CIBRS Offense Code  \
# 0                    Property                26B
# 1                     Society                35A
# 2                    Property                23H
# 3                      People                13A
# 4                     Society                35A
# ...                       ...                ...
# 510584                 People                13B
# 510585                 People                13A
# 510586               Property                120
# 510587                Society                35A
# 510588               Property                240
#
#                  CIBRS Offense Description  Victim UID Victim Category  \
# 0       Credit Card/Automatic Teller Fraud         NaN             NaN
# 1                 Drug/Narcotic Violations         NaN             NaN
# 2                        All Other Larceny         NaN             NaN
# 3                       Aggravated Assault    758591.0               I
# 4                 Drug/Narcotic Violations         NaN             NaN
# ...                                    ...         ...             ...
# 510584                      Simple Assault   2046757.0               I
# 510585                  Aggravated Assault   2047403.0               I
# 510586                             Robbery         NaN             NaN
# 510587            Drug/Narcotic Violations         NaN             NaN
# 510588                 Motor Vehicle Theft         NaN             NaN
#
#         Victim Age Victim Race  ...        CIBRS Status Date  Census Tract  \
# 0              NaN         NaN  ...  2021-12-30 21:45:25.000           NaN
# 1              NaN         NaN  ...  2022-06-08 17:33:54.000           NaN
# 2              NaN         NaN  ...  2021-12-30 17:23:07.999           NaN
# 3             34.0    HISPANIC  ...  2021-12-31 11:07:41.000           NaN
# 4              NaN         NaN  ...  2022-07-19 10:10:25.999           NaN
# ...            ...         ...  ...                      ...           ...
# 510584        55.0       BLACK  ...  2024-09-30 16:18:31.000          4.00
# 510585        37.0    HISPANIC  ...  2024-10-01 10:14:40.999         76.02
# 510586         NaN         NaN  ...  2024-10-03 10:22:24.999        105.02
# 510587         NaN         NaN  ...  2024-10-03 11:20:05.999         51.02
# 510588         NaN         NaN  ...  2024-10-01 20:06:28.999         83.60
#
#                       BCS Area 2022 Census Tract Population  \
# 0                OUT OF COUNTY                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3           DETENTION FACILITY                          NaN
# 4                          NaN                          NaN
# ...                        ...                          ...
# 510584                     NaN                       4270.0
# 510585                     NaN                       1781.0
# 510586  CITY OF IMPERIAL BEACH                       5177.0
# 510587                     NaN                       4314.0
# 510588                     NaN                       6108.0
#
#         2022 Zip Code Population  ZIP Code Crime Rate Per 1,000 People  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                        34003.0                                 0.029
# 3                            NaN                                   NaN
# 4                        33191.0                                 0.030
# ...                          ...                                   ...
# 510584                   34003.0                                 0.029
# 510585                   45561.0                                 0.022
# 510586                   26275.0                                 0.038
# 510587                   51482.0                                 0.019
# 510588                   79001.0                                 0.013
#
#                                           CT_Centroid  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 510584  POINT (-117.16294602963433 32.75323463050032)
# 510585  POINT (-117.25011244725232 32.76662199090993)
# 510586   POINT (-117.11291629315383 32.5860203137456)
# 510587  POINT (-117.15400405344477 32.70904613738133)
# 510588  POINT (-117.12951709677452 32.89988427938949)
#
#                                           ZIP_Centroid  Unique Victims  \
# 0                                                  NaN               1
# 1                                                  NaN               1
# 2       POINT (-117.16293543470877 32.745320835953024)               1
# 3                                                  NaN               1
# 4        POINT (-117.39278383065854 33.35683989585762)               1
# ...                                                ...             ...
# 510584  POINT (-117.16293543470877 32.745320835953024)               1
# 510585   POINT (-117.23328805118283 32.79627711318137)               1
# 510586   POINT (-117.11711989601122 32.57109719065306)               0
# 510587    POINT (-117.1798054992675 32.71654211170926)               1
# 510588   POINT (-117.1439759278231 32.908598185501646)               1
#
#        Victim Age Bins
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3             g) 30-34
# 4                  NaN
# ...                ...
# 510584        l) 55-59
# 510585        h) 35-39
# 510586             NaN
# 510587             NaN
# 510588             NaN
#
# [510589 rows x 30 columns]

# %%
crime = crime[crime['Crime Against Category'] == 'People']
crime
# Out:
#         Incident UID           Incident Date CIBRS Unique Offense ID  \
# 3             736456  01/17/2021 05:05:00 PM       736456-13A-758591
# 20            640887  02/16/2021 09:00:00 PM       640887-13B-657267
# 23            661987  02/18/2021 05:40:45 PM       661987-13A-679864
# 27            657630  02/25/2021 01:00:00 AM       657630-13B-675108
# 28            657631  02/25/2021 05:56:00 PM       657631-13B-675110
# ...              ...                     ...                     ...
# 510573       2332703  09/30/2024 12:56:10 AM     2332703-13B-2045943
# 510574       2332428  09/29/2024 01:44:00 AM     2332428-13A-2045641
# 510576       2341549  09/29/2024 11:19:00 PM     2341549-13A-2053249
# 510584       2333674  09/29/2024 07:00:00 PM     2333674-13B-2046757
# 510585       2334461  09/28/2024 12:00:01 AM     2334461-13A-2047403
#
#        Crime Against Category CIBRS Offense Code CIBRS Offense Description  \
# 3                      People                13A        Aggravated Assault
# 20                     People                13B            Simple Assault
# 23                     People                13A        Aggravated Assault
# 27                     People                13B            Simple Assault
# 28                     People                13B            Simple Assault
# ...                       ...                ...                       ...
# 510573                 People                13B            Simple Assault
# 510574                 People                13A        Aggravated Assault
# 510576                 People                13A        Aggravated Assault
# 510584                 People                13B            Simple Assault
# 510585                 People                13A        Aggravated Assault
#
#         Victim UID Victim Category  Victim Age Victim Race  ...  \
# 3         758591.0               I        34.0    HISPANIC  ...
# 20        657267.0               I        44.0    HISPANIC  ...
# 23        679864.0               I        22.0    HISPANIC  ...
# 27        675108.0               I        38.0       WHITE  ...
# 28        675110.0               I        33.0    HISPANIC  ...
# ...            ...             ...         ...         ...  ...
# 510573   2045943.0               I        59.0    HISPANIC  ...
# 510574   2045641.0               I         NaN         NaN  ...
# 510576   2053249.0               I        20.0    HISPANIC  ...
# 510584   2046757.0               I        55.0       BLACK  ...
# 510585   2047403.0               I        37.0    HISPANIC  ...
#
#               CIBRS Status Date  Census Tract            BCS Area  \
# 3       2021-12-31 11:07:41.000           NaN  DETENTION FACILITY
# 20      2022-01-01 04:47:39.000           NaN  DETENTION FACILITY
# 23      2022-01-01 07:29:38.000           NaN                 NaN
# 27      2022-01-01 07:15:05.999           NaN  DETENTION FACILITY
# 28      2022-01-01 07:15:12.999           NaN  DETENTION FACILITY
# ...                         ...           ...                 ...
# 510573  2024-09-30 04:07:28.999         48.00                 NaN
# 510574  2024-09-29 10:09:53.000        100.01                 NaN
# 510576  2024-10-07 16:17:52.999        191.05       VALLEY CENTER
# 510584  2024-09-30 16:18:31.000          4.00                 NaN
# 510585  2024-10-01 10:14:40.999         76.02                 NaN
#
#        2022 Census Tract Population  2022 Zip Code Population  \
# 3                               NaN                       NaN
# 20                              NaN                       NaN
# 23                              NaN                   37960.0
# 27                              NaN                       NaN
# 28                              NaN                       NaN
# ...                             ...                       ...
# 510573                       3109.0                   48645.0
# 510574                       4455.0                   84897.0
# 510576                       7186.0                   19513.0
# 510584                       4270.0                   34003.0
# 510585                       1781.0                   45561.0
#
#         ZIP Code Crime Rate Per 1,000 People  \
# 3                                        NaN
# 20                                       NaN
# 23                                     0.026
# 27                                       NaN
# 28                                       NaN
# ...                                      ...
# 510573                                 0.021
# 510574                                 0.012
# 510576                                 0.051
# 510584                                 0.029
# 510585                                 0.022
#
#                                           CT_Centroid  \
# 3                                                 NaN
# 20                                                NaN
# 23                                                NaN
# 27                                                NaN
# 28                                                NaN
# ...                                               ...
# 510573  POINT (-117.13814231177453 32.70845460584856)
# 510574   POINT (-117.0554431101726 32.58681509425518)
# 510576  POINT (-117.09667669439708 33.23059021186462)
# 510584  POINT (-117.16294602963433 32.75323463050032)
# 510585  POINT (-117.25011244725232 32.76662199090993)
#
#                                           ZIP_Centroid  Unique Victims  \
# 3                                                  NaN               1
# 20                                                 NaN               1
# 23       POINT (-117.25744919022421 32.84663254858464)               1
# 27                                                 NaN               1
# 28                                                 NaN               1
# ...                                                ...             ...
# 510573  POINT (-117.12067829999555 32.693011151692495)               1
# 510574   POINT (-116.97504946156067 32.57385941287214)               1
# 510576   POINT (-117.00267067696717 33.26358696243767)               1
# 510584  POINT (-117.16293543470877 32.745320835953024)               1
# 510585   POINT (-117.23328805118283 32.79627711318137)               1
#
#        Victim Age Bins
# 3             g) 30-34
# 20            i) 40-44
# 23            e) 20-24
# 27            h) 35-39
# 28            g) 30-34
# ...                ...
# 510573        l) 55-59
# 510574             NaN
# 510576        e) 20-24
# 510584        l) 55-59
# 510585        h) 35-39
#
# [123750 rows x 30 columns]

# %%
crime.columns
# Out:
# Index(['Incident UID', 'Incident Date', 'CIBRS Unique Offense ID',
#        'Crime Against Category', 'CIBRS Offense Code',
#        'CIBRS Offense Description', 'Victim UID', 'Victim Category',
#        'Victim Age', 'Victim Race', 'Victim Sex', 'Stolen Vehicles', 'Beat',
#        'City', 'Zip Code', 'Domestic Violence Incident', 'Agency',
#        'Unique Incidents', 'Unique Offenses', 'CIBRS Status',
#        'CIBRS Status Date', 'Census Tract', 'BCS Area',
#        '2022 Census Tract Population', '2022 Zip Code Population',
#        'ZIP Code Crime Rate Per 1,000 People', 'CT_Centroid', 'ZIP_Centroid',
#        'Unique Victims', 'Victim Age Bins'],
#       dtype='object')

# %%
crime = crime[['Incident UID', 'Incident Date', 'Crime Against Category', 'Zip Code', 'ZIP_Centroid']]
crime
# Out:
#         Incident UID           Incident Date Crime Against Category  Zip Code  \
# 3             736456  01/17/2021 05:05:00 PM                 People       NaN
# 20            640887  02/16/2021 09:00:00 PM                 People       NaN
# 23            661987  02/18/2021 05:40:45 PM                 People   92037.0
# 27            657630  02/25/2021 01:00:00 AM                 People       NaN
# 28            657631  02/25/2021 05:56:00 PM                 People       NaN
# ...              ...                     ...                    ...       ...
# 510573       2332703  09/30/2024 12:56:10 AM                 People   92113.0
# 510574       2332428  09/29/2024 01:44:00 AM                 People   92154.0
# 510576       2341549  09/29/2024 11:19:00 PM                 People   92082.0
# 510584       2333674  09/29/2024 07:00:00 PM                 People   92103.0
# 510585       2334461  09/28/2024 12:00:01 AM                 People   92109.0
#
#                                           ZIP_Centroid
# 3                                                  NaN
# 20                                                 NaN
# 23       POINT (-117.25744919022421 32.84663254858464)
# 27                                                 NaN
# 28                                                 NaN
# ...                                                ...
# 510573  POINT (-117.12067829999555 32.693011151692495)
# 510574   POINT (-116.97504946156067 32.57385941287214)
# 510576   POINT (-117.00267067696717 33.26358696243767)
# 510584  POINT (-117.16293543470877 32.745320835953024)
# 510585   POINT (-117.23328805118283 32.79627711318137)
#
# [123750 rows x 5 columns]

# %%
crime = crime.dropna(subset = ['Zip Code'])
crime
# Out:
#         Incident UID           Incident Date Crime Against Category  Zip Code  \
# 23            661987  02/18/2021 05:40:45 PM                 People   92037.0
# 73            721771  05/04/2021 06:54:00 PM                 People   92011.0
# 96            941769  06/05/2021 09:20:00 AM                 People   92020.0
# 147           976822  08/04/2021 03:22:00 PM                 People   92109.0
# 194          2163563  10/28/2021 11:20:00 AM                 People   92101.0
# ...              ...                     ...                    ...       ...
# 510573       2332703  09/30/2024 12:56:10 AM                 People   92113.0
# 510574       2332428  09/29/2024 01:44:00 AM                 People   92154.0
# 510576       2341549  09/29/2024 11:19:00 PM                 People   92082.0
# 510584       2333674  09/29/2024 07:00:00 PM                 People   92103.0
# 510585       2334461  09/28/2024 12:00:01 AM                 People   92109.0
#
#                                           ZIP_Centroid
# 23       POINT (-117.25744919022421 32.84663254858464)
# 73       POINT (-117.29545435808339 33.10813455386477)
# 96      POINT (-116.96612641411997 32.794739363541865)
# 147      POINT (-117.23328805118283 32.79627711318137)
# 194       POINT (-117.1798054992675 32.71654211170926)
# ...                                                ...
# 510573  POINT (-117.12067829999555 32.693011151692495)
# 510574   POINT (-116.97504946156067 32.57385941287214)
# 510576   POINT (-117.00267067696717 33.26358696243767)
# 510584  POINT (-117.16293543470877 32.745320835953024)
# 510585   POINT (-117.23328805118283 32.79627711318137)
#
# [121366 rows x 5 columns]

# %%
grouped_crime = crime.groupby('Zip Code').count().sort_values('Incident UID', ascending = False)
grouped_crime = grouped_crime.get('Incident UID')
grouped_crime = grouped_crime.assign()
grouped_crime
# Out:
# Zip Code
# 92101.0    10885
# 91910.0     3711
# 92113.0     3602
# 92054.0     3490
# 91950.0     3353
#            ...
# 92134.0        5
# 91948.0        5
# 92155.0        4
# 92118.0        2
# 92096.0        1
# Name: Incident UID, Length: 112, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/fj/nnphscc51ydgzq5pylw9n6w80000gn/T/ipykernel_57756/2193088328.py in ?()
#      10 # Replace this with your real crime Series after you've loaded and processed it
#      11 crime_data = grouped_crime
#      12 # Merge crime data with GeoJSON data on 'Zip Code' field
#      13 # Replace 'zipcode_column_in_geojson' with the actual column name in GeoJSON that matches the zip codes
# ---> 14 map_data = zipcodes_gdf.merge(crime_data, left_on="zipcode_column_in_geojson", right_on="Zip Code", how="left")
#      15
#      16 # Initialize the map centered on San Diego
#      17 crime_map = folium.Map(location=[32.7157, -117.1611], zoom_start=11)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9839         validate: str | None = None,
#    9840     ) -> DataFrame:
#    9841         from pandas.core.reshape.merge import merge
#    9842
# -> 9843         return merge(
#    9844             self,
#    9845             right,
#    9846             how=how,
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     144     copy: bool | None = None,
#     145     indicator: str | bool = False,
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     733         (
#     734             self.left_join_keys,
#     735             self.right_join_keys,
#     736             self.join_names,
# --> 737         ) = self._get_merge_keys()
#     738
#     739         # validate the merge keys dtypes. We may need to coerce
#     740         # to avoid incompatible dtypes
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1217                     if lk is not None:
#    1218                         # Then we're either Hashable or a wrong-length arraylike,
#    1219                         #  the latter of which will raise
#    1220                         lk = cast(Hashable, lk)
# -> 1221                         left_keys.append(left._get_label_or_level_values(lk))
#    1222                         join_names.append(lk)
#    1223                     else:
#    1224                         # work-around for merge_asof(left_index=True)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'zipcode_column_in_geojson'

# %%
# Assuming your Series is named crime_series
crime_series = crime_series.rename_axis('Zip Code').reset_index(name='Crime Count')
crime_series.to_json("crime_data.json", orient="records")
